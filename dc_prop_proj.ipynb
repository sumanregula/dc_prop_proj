# %%
#The following is to load the csv file into a dataframe
import pandas as pd
import numpy as np

filename = 'DC_Properties.csv'
df = pd.read_csv(filename)

df.head()
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    ID  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM     AYB  \
# 0   0       4          0      Warm Cool  Y        2.0      8      4  1910.0
# 1   1       3          1      Warm Cool  Y        2.0     11      5  1898.0
# 2   2       3          1  Hot Water Rad  Y        2.0      9      5  1910.0
# 3   3       3          1  Hot Water Rad  Y        2.0      8      5  1900.0
# 4   4       2          1      Warm Cool  Y        1.0     11      3  1913.0
#
#    YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0   1988.0   ...    -77.040832       Old City 2   040 D Old City 2
# 1   2007.0   ...    -77.040764       Old City 2   040 D Old City 2
# ...

# %%
# the following code is to check the list of columns
df.columns
# Out:
# Index(['ID', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
# running the following command shows the number of rows
# 158957
df
# Out:
#             ID  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0            0       4          0      Warm Cool  Y        2.0      8      4
# 1            1       3          1      Warm Cool  Y        2.0     11      5
# 2            2       3          1  Hot Water Rad  Y        2.0      9      5
# 3            3       3          1  Hot Water Rad  Y        2.0      8      5
# 4            4       2          1      Warm Cool  Y        1.0     11      3
# 5            5       3          2  Hot Water Rad  Y        1.0     10      5
# 6            6       1          0      Warm Cool  Y        2.0      5      2
# 7            7       3          1  Hot Water Rad  Y        2.0      8      4
# 8            8       3          1      Warm Cool  Y        2.0      7      3
# 9            9       1          1  Hot Water Rad  Y        1.0      6      2
# 10          10       3          0     Forced Air  N        3.0     12      5
# ...

# %%
# see if there are any null values
df[df['BATHRM'].isnull() | df['HF_BATHRM'].isnull() | df['HEAT'].isnull() | df['AC'].isnull() | df['NUM_UNITS'].isnull() | df['ROOMS'].isnull() | df['BEDRM'].isnull() | df['AYB'].isnull() | df['YR_RMDL'].isnull() | df['EYB'].isnull() | df['STORIES'].isnull() | df['SALEDATE'].isnull() | df['PRICE'].isnull() | df['QUALIFIED'].isnull() | df['SALE_NUM'].isnull() | df['GBA'].isnull() | df['BLDG_NUM'].isnull() | df['STYLE'].isnull() | df['STRUCT'].isnull() | df['GRADE'].isnull() | df['CNDTN'].isnull() | df['EXTWALL'].isnull() | df['ROOF'].isnull() | df['INTWALL'].isnull() | df['KITCHENS'].isnull() | df['FIREPLACES'].isnull() | df['USECODE'].isnull() | df['LANDAREA'].isnull() | df['GIS_LAST_MOD_DTTM'].isnull() | df['SOURCE'].isnull() | df['CMPLX_NUM'].isnull() | df['LIVING_GBA'].isnull() | df['FULLADDRESS'].isnull() | df['CITY'].isnull() | df['STATE'].isnull() | df['ZIPCODE'].isnull() | df['NATIONALGRID'].isnull() | df['LATITUDE'].isnull() | df['LONGITUDE'].isnull() | df['ASSESSMENT_NBHD'].isnull() | df['ASSESSMENT_SUBNBHD'].isnull() | df['CENSUS_TRACT'].isnull() | df['CENSUS_BLOCK'].isnull() | df['WARD'].isnull() | df['SQUARE'].isnull() | df['X'].isnull() | df['Y'].isnull() | df['QUADRANT'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0            0       4          0      Warm Cool  Y        2.0      8      4
# 1            1       3          1      Warm Cool  Y        2.0     11      5
# 2            2       3          1  Hot Water Rad  Y        2.0      9      5
# 3            3       3          1  Hot Water Rad  Y        2.0      8      5
# 4            4       2          1      Warm Cool  Y        1.0     11      3
# 5            5       3          2  Hot Water Rad  Y        1.0     10      5
# 6            6       1          0      Warm Cool  Y        2.0      5      2
# 7            7       3          1  Hot Water Rad  Y        2.0      8      4
# 8            8       3          1      Warm Cool  Y        2.0      7      3
# 9            9       1          1  Hot Water Rad  Y        1.0      6      2
# 10          10       3          0     Forced Air  N        3.0     12      5
# ...

# %%
# see if there are rows with all non-null values
df[df['BATHRM'].notnull() & df['HF_BATHRM'].notnull() & df['HEAT'].notnull() & df['AC'].notnull() & df['NUM_UNITS'].notnull() & df['ROOMS'].notnull() & df['BEDRM'].notnull() & df['AYB'].notnull() & df['YR_RMDL'].notnull() & df['EYB'].notnull() & df['STORIES'].notnull() & df['SALEDATE'].notnull() & df['PRICE'].notnull() & df['QUALIFIED'].notnull() & df['SALE_NUM'].notnull() & df['GBA'].notnull() & df['BLDG_NUM'].notnull() & df['STYLE'].notnull() & df['STRUCT'].notnull() & df['GRADE'].notnull() & df['CNDTN'].notnull() & df['EXTWALL'].notnull() & df['ROOF'].notnull() & df['INTWALL'].notnull() & df['KITCHENS'].notnull() & df['FIREPLACES'].notnull() & df['USECODE'].notnull() & df['LANDAREA'].notnull() & df['GIS_LAST_MOD_DTTM'].notnull() & df['SOURCE'].notnull() & df['CMPLX_NUM'].notnull() & df['LIVING_GBA'].notnull() & df['FULLADDRESS'].notnull() & df['CITY'].notnull() & df['STATE'].notnull() & df['ZIPCODE'].notnull() & df['NATIONALGRID'].notnull() & df['LATITUDE'].notnull() & df['LONGITUDE'].notnull() & df['ASSESSMENT_NBHD'].notnull() & df['ASSESSMENT_SUBNBHD'].notnull() & df['CENSUS_TRACT'].notnull() & df['CENSUS_BLOCK'].notnull() & df['WARD'].notnull() & df['SQUARE'].notnull() & df['X'].notnull() & df['Y'].notnull() & df['QUADRANT'].notnull()]
# Out:
# Empty DataFrame
# Columns: [ID, BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT]
# Index: []
#
# [0 rows x 49 columns]

# %%
df[df['ZIPCODE'].isnull() | df['LATITUDE'].isnull() | df['LONGITUDE'].isnull() | df['ASSESSMENT_NBHD'].isnull() | df['CENSUS_TRACT'].isnull() | df['WARD'].isnull() ]
# Out:
#             ID  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 104610  104610       2          0  Hot Water Rad  N        2.0     11      4
#
#            AYB  YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD  \
# 104610  1938.0      NaN   ...           NaN              NaN
#
#        ASSESSMENT_SUBNBHD  CENSUS_TRACT CENSUS_BLOCK  WARD  SQUARE   X   Y  \
# 104610                NaN           NaN          NaN   NaN    PAR  NaN NaN
#
#        QUADRANT
# 104610      NaN
#
# [1 rows x 49 columns]

# %%
df[df['ZIPCODE'].isnull() & df['LATITUDE'].isnull() & df['LONGITUDE'].isnull() & df['ASSESSMENT_NBHD'].isnull() & df['CENSUS_TRACT'].isnull() & df['WARD'].isnull() ]
# Out:
#             ID  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 104610  104610       2          0  Hot Water Rad  N        2.0     11      4
#
#            AYB  YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD  \
# 104610  1938.0      NaN   ...           NaN              NaN
#
#        ASSESSMENT_SUBNBHD  CENSUS_TRACT CENSUS_BLOCK  WARD  SQUARE   X   Y  \
# 104610                NaN           NaN          NaN   NaN    PAR  NaN NaN
#
#        QUADRANT
# 104610      NaN
#
# [1 rows x 49 columns]

# %%
df.dropna(subset=['ZIPCODE','LATITUDE','LONGITUDE','ASSESSMENT_NBHD','CENSUS_TRACT','WARD'], inplace=True)

# %%
df[df['NUM_UNITS'].isnull() | df['AYB'].isnull() | df['YR_RMDL'].isnull() | df['STORIES'].isnull() | df['SALEDATE'].isnull() | df['PRICE'].isnull() | df['GBA'].isnull() | df['STYLE'].isnull() | df['STRUCT'].isnull() | df['GRADE'].isnull() | df['CNDTN'].isnull() | df['EXTWALL'].isnull() | df['ROOF'].isnull() | df['INTWALL'].isnull() | df['KITCHENS'].isnull() | df['CMPLX_NUM'].isnull() | df['LIVING_GBA'].isnull() | df['FULLADDRESS'].isnull() | df['CITY'].isnull() | df['STATE'].isnull() | df['NATIONALGRID'].isnull() | df['ASSESSMENT_SUBNBHD'].isnull() | df['CENSUS_BLOCK'].isnull() | df['X'].isnull() | df['Y'].isnull() | df['QUADRANT'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0            0       4          0      Warm Cool  Y        2.0      8      4
# 1            1       3          1      Warm Cool  Y        2.0     11      5
# 2            2       3          1  Hot Water Rad  Y        2.0      9      5
# 3            3       3          1  Hot Water Rad  Y        2.0      8      5
# 4            4       2          1      Warm Cool  Y        1.0     11      3
# 5            5       3          2  Hot Water Rad  Y        1.0     10      5
# 6            6       1          0      Warm Cool  Y        2.0      5      2
# 7            7       3          1  Hot Water Rad  Y        2.0      8      4
# 8            8       3          1      Warm Cool  Y        2.0      7      3
# 9            9       1          1  Hot Water Rad  Y        1.0      6      2
# 10          10       3          0     Forced Air  N        3.0     12      5
# ...

# %%
df[df['NUM_UNITS'].isnull() & df['AYB'].isnull() & df['YR_RMDL'].isnull() & df['STORIES'].isnull() & df['SALEDATE'].isnull() & df['PRICE'].isnull() & df['GBA'].isnull() & df['STYLE'].isnull() & df['STRUCT'].isnull() & df['GRADE'].isnull() & df['CNDTN'].isnull() & df['EXTWALL'].isnull() & df['ROOF'].isnull() & df['INTWALL'].isnull() & df['KITCHENS'].isnull() & df['CMPLX_NUM'].isnull() & df['LIVING_GBA'].isnull() & df['FULLADDRESS'].isnull() & df['CITY'].isnull() & df['STATE'].isnull() & df['NATIONALGRID'].isnull() & df['ASSESSMENT_SUBNBHD'].isnull() & df['CENSUS_BLOCK'].isnull() & df['X'].isnull() & df['Y'].isnull() & df['QUADRANT'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID, BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT]
# Index: []
#
# [0 rows x 49 columns]

# %%
df[df['NUM_UNITS'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM        HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 106696  106696       2          0  Forced Air  Y        NaN      4      2
# 106697  106697       2          0  Forced Air  Y        NaN      4      2
# 106698  106698       2          0  Forced Air  Y        NaN      4      2
# 106699  106699       2          0  Forced Air  Y        NaN      4      2
# 106700  106700       2          0  Forced Air  Y        NaN      4      2
# 106701  106701       2          0  Forced Air  Y        NaN      4      2
# 106702  106702       2          0  Forced Air  Y        NaN      4      2
# 106703  106703       2          0  Forced Air  Y        NaN      4      2
# 106704  106704       2          0  Forced Air  Y        NaN      4      2
# 106705  106705       2          0  Forced Air  Y        NaN      4      2
# 106706  106706       2          0  Forced Air  Y        NaN      4      2
# 106707  106707       2          0  Forced Air  Y        NaN      4      2
# ...

# %%
df['NUM_UNITS'].fillna(0, inplace=True)

# %%
df[df['LIVING_GBA'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0            0       4          0      Warm Cool  Y        2.0      8      4
# 1            1       3          1      Warm Cool  Y        2.0     11      5
# 2            2       3          1  Hot Water Rad  Y        2.0      9      5
# 3            3       3          1  Hot Water Rad  Y        2.0      8      5
# 4            4       2          1      Warm Cool  Y        1.0     11      3
# 5            5       3          2  Hot Water Rad  Y        1.0     10      5
# 6            6       1          0      Warm Cool  Y        2.0      5      2
# 7            7       3          1  Hot Water Rad  Y        2.0      8      4
# 8            8       3          1      Warm Cool  Y        2.0      7      3
# 9            9       1          1  Hot Water Rad  Y        1.0      6      2
# 10          10       3          0     Forced Air  N        3.0     12      5
# ...

# %%
df
# Out:
#             ID  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0            0       4          0      Warm Cool  Y        2.0      8      4
# 1            1       3          1      Warm Cool  Y        2.0     11      5
# 2            2       3          1  Hot Water Rad  Y        2.0      9      5
# 3            3       3          1  Hot Water Rad  Y        2.0      8      5
# 4            4       2          1      Warm Cool  Y        1.0     11      3
# 5            5       3          2  Hot Water Rad  Y        1.0     10      5
# 6            6       1          0      Warm Cool  Y        2.0      5      2
# 7            7       3          1  Hot Water Rad  Y        2.0      8      4
# 8            8       3          1      Warm Cool  Y        2.0      7      3
# 9            9       1          1  Hot Water Rad  Y        1.0      6      2
# 10          10       3          0     Forced Air  N        3.0     12      5
# ...

# %%
df['LIVING_GBA']
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23           NaN
# 24           NaN
# 25           NaN
# 26           NaN
# 27           NaN
# 28           NaN
# 29           NaN
#            ...
# 158927    1342.0
# 158928    1100.0
# 158929    1130.0
# 158930     990.0
# 158931     920.0
# 158932     942.0
# 158933     795.0
# 158934     671.0
# 158935     551.0
# 158936     644.0
# 158937     825.0
# 158938    1413.0
# 158939     825.0
# 158940    1413.0
# 158941     861.0
# 158942    1492.0
# 158943    1838.0
# 158944    1938.0
# 158945     659.0
# 158946     818.0
# 158947     809.0
# ...
